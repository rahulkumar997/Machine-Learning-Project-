# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from sklearn.model_selection
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('species',axis = 1)
y = df['species']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.33 , random_state = 42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.score(x_test,y_test)
# Out:
# 1.0

# %%
model_knn.predict(x_test)
# Out:
# array(['versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'virginica', 'versicolor', 'versicolor',
#        'virginica', 'setosa', 'setosa', 'setosa', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'virginica', 'setosa',
#        'virginica', 'setosa', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'setosa', 'setosa', 'setosa', 'setosa',
#        'versicolor', 'setosa', 'setosa', 'virginica', 'versicolor',
#        'setosa', 'setosa', 'setosa', 'virginica', 'versicolor',
#        'versicolor', 'setosa', 'setosa', 'versicolor', 'virginica',
#        'virginica', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC(C = 30 , kernel = 'rbf',gamma = 'auto')

# %%
model_svm.fit(x_train,y_train)
# Out:
# SVC(C=30, gamma='auto')

# %%
model_svm.score(x_test,y_test)
# Out:
# 0.98

# %%
model_svm.predict(x_test)
# Out:
# array(['versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'virginica', 'versicolor', 'versicolor',
#        'virginica', 'setosa', 'setosa', 'setosa', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'virginica', 'setosa',
#        'virginica', 'setosa', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'setosa', 'setosa', 'setosa', 'setosa',
#        'versicolor', 'setosa', 'setosa', 'virginica', 'versicolor',
#        'setosa', 'setosa', 'setosa', 'virginica', 'versicolor',
#        'versicolor', 'setosa', 'setosa', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'virginica'], dtype=object)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# now let use the gridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# Assuming model_svm is already defined, e.g., model_svm = SVC()

classifier = GridSearchCV(
    estimator=model_svm,
    param_grid={
        'C': [1, 10, 20, 30],
        'kernel': ['rbf', 'linear']
    },
    cv=5,
    return_train_score=False
)

# %%
classifier.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(C=30, gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00320234, 0.00218816, 0.00229616, 0.00214815, 0.00245094,
#         0.00215797, 0.00229712, 0.00213704]),
#  'std_fit_time': array([5.30487041e-04, 5.41245674e-05, 8.92799620e-05, 6.24731292e-05,
#         2.18031047e-04, 8.22744345e-05, 6.62081826e-05, 6.07183550e-05]),
#  'mean_score_time': array([0.00256658, 0.00169311, 0.00170622, 0.00159631, 0.00181832,
#         0.00165682, 0.00167265, 0.00160451]),
#  'std_score_time': array([9.15115880e-04, 6.14662518e-05, 9.10000460e-05, 1.98936554e-05,
#         2.15170177e-04, 8.64623457e-05, 5.30971825e-05, 2.98445974e-05]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
# ...

# %%
results = pd.DataFrame(classifier.cv_results_)
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.003202      0.000530         0.002567        0.000915        1
# 1       0.002188      0.000054         0.001693        0.000061        1
# 2       0.002296      0.000089         0.001706        0.000091       10
# 3       0.002148      0.000062         0.001596        0.000020       10
# 4       0.002451      0.000218         0.001818        0.000215       20
# 5       0.002158      0.000082         0.001657        0.000086       20
# 6       0.002297      0.000066         0.001673        0.000053       30
# 7       0.002137      0.000061         0.001605        0.000030       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# ...

# %%
results[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVC

# Example base model
model_svm = SVC()

# Correct RandomizedSearchCV
classifier_r = RandomizedSearchCV(
    estimator=model_svm,
    param_distributions={
        'C': [1, 10, 20, 30],
        'kernel': ['rbf', 'linear']
    },
    n_iter=4,
    cv=5,
    return_train_score=False
)

# %%
classifier_r.fit(x,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(), n_iter=4,
#                    param_distributions={'C': [1, 10, 20, 30],
#                                         'kernel': ['rbf', 'linear']})

# %%
results = pd.DataFrame(classifier_r.cv_results_)
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.007167      0.001694         0.008688        0.002471          rbf
# 1       0.006136      0.003351         0.004675        0.003306       linear
# 2       0.006056      0.002514         0.005176        0.002724          rbf
# 3       0.004311      0.000826         0.003343        0.000998          rbf
#
#    param_C                         params  split0_test_score  \
# 0       20     {'kernel': 'rbf', 'C': 20}           0.966667
# 1       10  {'kernel': 'linear', 'C': 10}           1.000000
# 2        1      {'kernel': 'rbf', 'C': 1}           0.966667
# 3       30     {'kernel': 'rbf', 'C': 30}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           1.000000           0.966667           0.966667                1.0
# 1           1.000000           0.900000           0.966667                1.0
# ...

# %%
classifier_r.best_params_
# Out:
# {'kernel': 'rbf', 'C': 20}

# %%
classifier_r.best_score_
# Out:
# np.float64(0.9800000000000001)

# %%
classifier_r.best_estimator_
# Out:
# SVC(C=20)

# %%
classifier_r.best_index_
# Out:
# np.int64(0)

# %%
classifier_r.cv_results_
# Out:
# {'mean_fit_time': array([0.00716729, 0.0061357 , 0.00605593, 0.00431108]),
#  'std_fit_time': array([0.00169398, 0.0033514 , 0.00251448, 0.00082628]),
#  'mean_score_time': array([0.00868802, 0.00467505, 0.00517645, 0.00334301]),
#  'std_score_time': array([0.00247083, 0.00330587, 0.00272396, 0.00099783]),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'rbf'],
#               mask=[False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_C': masked_array(data=[20, 10, 1, 30],
#               mask=[False, False, False, False],
#         fill_value=999999),
#  'params': [{'kernel': 'rbf', 'C': 20},
#   {'kernel': 'linear', 'C': 10},
#   {'kernel': 'rbf', 'C': 1},
#   {'kernel': 'rbf', 'C': 30}],
#  'split0_test_score': array([0.96666667, 1.        , 0.96666667, 0.96666667]),
#  'split1_test_score': array([1.        , 1.        , 0.96666667, 1.        ]),
# ...

# %%
results[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0       20          rbf         0.980000
# 1       10       linear         0.973333
# 2        1          rbf         0.966667
# 3       30          rbf         0.973333
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['param_C'].plot(kind='hist', bins=20, title='param_C')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['mean_test_score'].plot(kind='hist', bins=20, title='mean_test_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
