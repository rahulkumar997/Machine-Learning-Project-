# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\kumar\Downloads\Ecommerce dataset.csv")
df
# Out:
#         OrderID               Product     Category    Brand Platform  \
# 0     ORD100000    Samsung Galaxy A14  Electronics  Samsung     Souq
# 1     ORD100001          Nike Air Max      Fashion     Nike    Jumia
# 2     ORD100002     Bluetooth Headset  Accessories      JBL    Jumia
# 3     ORD100003    HP Pavilion Laptop    Computers       HP     Souq
# 4     ORD100004             iPhone 13  Electronics    Apple     Souq
# ...         ...                   ...          ...      ...      ...
# 9995  ORD109995    HP Pavilion Laptop    Computers       HP    Jumia
# 9996  ORD109996  Adidas Running Shoes      Fashion   Adidas     Souq
# 9997  ORD109997  Adidas Running Shoes      Fashion   Adidas   Amazon
# 9998  ORD109998        T-shirt Cotton      Fashion  Generic   Amazon
# 9999  ORD109999     Bluetooth Headset  Accessories      JBL    Jumia
#
#             City     Price  Quantity  TotalAmount  Rating  Reviews   OrderDate
# ...

# %%
df.head()
# Out:
#      OrderID             Product     Category    Brand Platform        City  \
# 0  ORD100000  Samsung Galaxy A14  Electronics  Samsung     Souq       Cairo
# 1  ORD100001        Nike Air Max      Fashion     Nike    Jumia  Alexandria
# 2  ORD100002   Bluetooth Headset  Accessories      JBL    Jumia  Casablanca
# 3  ORD100003  HP Pavilion Laptop    Computers       HP     Souq       Dubai
# 4  ORD100004           iPhone 13  Electronics    Apple     Souq  Casablanca
#
#       Price  Quantity  TotalAmount  Rating  Reviews   OrderDate
# 0  16284.02         1     16284.02    1.39     1684  11-11-2024
# 1   6645.20         2     13290.40    2.56     3604  22-06-2024
# 2   8882.92         3     26648.76    4.98     1257  27-05-2024
# 3   3665.44         1      3665.44    1.44      662  25-07-2024
# 4   5210.37         2     10420.74    3.73     2424  19-02-2024

# %%
df.tail()
# Out:
#         OrderID               Product     Category    Brand Platform  \
# 9995  ORD109995    HP Pavilion Laptop    Computers       HP    Jumia
# 9996  ORD109996  Adidas Running Shoes      Fashion   Adidas     Souq
# 9997  ORD109997  Adidas Running Shoes      Fashion   Adidas   Amazon
# 9998  ORD109998        T-shirt Cotton      Fashion  Generic   Amazon
# 9999  ORD109999     Bluetooth Headset  Accessories      JBL    Jumia
#
#             City     Price  Quantity  TotalAmount  Rating  Reviews   OrderDate
# 9995      Riyadh   3571.93         1      3571.93    1.05     2154  21-05-2024
# 9996       Cairo   2974.55         4     11898.20    2.60     1796  27-11-2024
# 9997      Riyadh   8646.20         1      8646.20    3.20     4001  15-10-2024
# 9998      Riyadh   4960.53         4     19842.12    3.42      685  26-04-2024
# 9999  Casablanca  13811.49         5     69057.45    2.84      488  15-01-2024

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      10000 non-null  object
#  1   Product      10000 non-null  object
#  2   Category     10000 non-null  object
#  3   Brand        10000 non-null  object
#  4   Platform     10000 non-null  object
#  5   City         10000 non-null  object
#  6   Price        10000 non-null  float64
#  7   Quantity     10000 non-null  int64
#  8   TotalAmount  10000 non-null  float64
#  9   Rating       10000 non-null  float64
#  10  Reviews      10000 non-null  int64
#  11  OrderDate    10000 non-null  object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 937.6+ KB

# %%
df.isnull()
# Out:
#       OrderID  Product  Category  Brand  Platform   City  Price  Quantity  \
# 0       False    False     False  False     False  False  False     False
# 1       False    False     False  False     False  False  False     False
# 2       False    False     False  False     False  False  False     False
# 3       False    False     False  False     False  False  False     False
# 4       False    False     False  False     False  False  False     False
# ...       ...      ...       ...    ...       ...    ...    ...       ...
# 9995    False    False     False  False     False  False  False     False
# 9996    False    False     False  False     False  False  False     False
# 9997    False    False     False  False     False  False  False     False
# 9998    False    False     False  False     False  False  False     False
# 9999    False    False     False  False     False  False  False     False
#
#       TotalAmount  Rating  Reviews  OrderDate
# ...

# %%
df.isnull().sum()
# Out:
# OrderID        0
# Product        0
# Category       0
# Brand          0
# Platform       0
# City           0
# Price          0
# Quantity       0
# TotalAmount    0
# Rating         0
# Reviews        0
# OrderDate      0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.columns
# Out:
# Index(['OrderID', 'Product', 'Category', 'Brand', 'Platform', 'City', 'Price',
#        'Quantity', 'TotalAmount', 'Rating', 'Reviews', 'OrderDate'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Price      Quantity   TotalAmount        Rating       Reviews
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean   10027.986331      3.006200  30199.572439      3.005592   2520.072200
# std     5728.261196      1.415472  23861.789828      1.154845   1443.849734
# min      105.590000      1.000000    113.550000      1.000000      0.000000
# 25%     4999.862500      2.000000  11066.910000      2.010000   1275.000000
# 50%    10063.600000      3.000000  23671.630000      3.005000   2537.500000
# 75%    14938.430000      4.000000  44648.580000      4.000000   3767.000000
# max    19999.340000      5.000000  99993.800000      5.000000   5000.000000

# %%
df.dtypes
# Out:
# OrderID         object
# Product         object
# Category        object
# Brand           object
# Platform        object
# City            object
# Price          float64
# Quantity         int64
# TotalAmount    float64
# Rating         float64
# Reviews          int64
# OrderDate       object
# dtype: object

# %%
def show_fig():
    plt.tight_layout()
    plt.show()
plot_no=1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Category')

plt.title(f'{plot_no}. Order Distribution Across Product Categories')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plot_no += 1

# %%
fig=plt.figure(figsize=(14,10))
sns.countplot(data=df , x='Product')
plt.title(f'{plot_no} . Types of Product are Avaliable')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df , x='Category' , y='TotalAmount' , estimator=sum)
plt.title(f'{plot_no} . Total Revenue Contribution by Category')
show_fig()
plot_no +=1

# %%
fig=plt.figure(figsize=(14,10))
sns.countplot(data=df , x='Brand')
plt.title(f'{plot_no} . Types of Brand are Avaliable')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(14,10))
sns.barplot(data=df , x='City' , y='OrderDate',estimator=sum)
plt.title(f'{plot_no}. More Order City')
show_fig()

# %%
fig = plt.figure(figsize=(14,10))
sns.barplot(data=df , x='Brand' , y='Price',estimator=sum)
plt.title(f'{plot_no}. More Order City')
show_fig()

# %%
fig = plt.figure(figsize=(14,10))
sns.barplot(data=df , x='Platform' , y='TotalAmount',estimator=sum)
plt.title(f'{plot_no}. platform-wise Revenue Comparison')
show_fig()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='City')
plt.title(f'{plot_no}. Order Volume by City')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Category', y='Price')
plt.title(f'{plot_no}. Price Distribution Across Categories')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Platform', y='Rating')
plt.title(f'{plot_no}. Rating Variability by Platform')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['Price'], kde=True,color='red')
plt.title(f'{plot_no}. Price Distribution of All Products')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['TotalAmount'], kde=True)
plt.title(f'{plot_no}. Distribution of Transaction Values')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Price', y='TotalAmount', hue='Category')
plt.title(f'{plot_no}. Relationship Between Price and Total Transaction Amount')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Brand', y='TotalAmount', estimator=sum)
plt.title(f'{plot_no}. Brand-wise Revenue Performance')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Brand', y='Rating')
plt.title(f'{plot_no}. Average Customer Rating by Brand')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.lineplot(data=df.sort_values('OrderDate'), x='OrderDate', y='TotalAmount')
plt.title(f'{plot_no}. Revenue Trend Over Time')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Platform', hue='Category')
plt.title(f'{plot_no}. Category Mix Across Platforms')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='City', y='TotalAmount')
plt.title(f'{plot_no}. City-wise Transaction Value Distribution')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Quantity', y='TotalAmount')
plt.title(f'{plot_no}. Impact of Quantity on Transaction Amount')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.violinplot(data=df, x='Category', y='Rating')
plt.title(f'{plot_no}. Rating Density Across Product Categories')
show_fig()
plot_no += 1
